# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivaranjani1311/AIML/blob/main/EXPT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')

path = "/content/drive/MyDrive/weight of copper - weight of copper.csv"

df = pd.read_csv(path)
df
# Out:
# Mounted at /content/drive
#      Unnamed: 0  power_rating  weight_of_copper category
# 0             0         16.46             34.69     high
# 1             1         12.52             28.78     high
# 2             2          7.66             21.48     high
# 3             3         21.09             41.64     high
# 4             4         24.43             46.64     high
# ..          ...           ...               ...      ...
# 495         495         32.82             59.23     high
# 496         496          8.46             22.69     high
# 497         497         39.51             69.27     high
# 498         498         29.60             54.40     high
# 499         499         32.20             58.30     high
#
# [500 rows x 4 columns]

# %%
plt.xlabel('POWER RATING')
plt.ylabel('AMOUNT OF COPPER')
plt.title('COPPER PREDICTION IN GENERATOR')
plt.hist(df[['power_rating', 'weight_of_copper']])
# Out:
# (array([[ 84., 118.,  82.,  84.,  76.,  56.,   0.,   0.,   0.,   0.],
#         [  0.,  21.,  59.,  88.,  61.,  51.,  66.,  46.,  51.,  57.]]),
#  array([ 5.05 , 13.032, 21.014, 28.996, 36.978, 44.96 , 52.942, 60.924,
#         68.906, 76.888, 84.87 ]),
#  <a list of 2 BarContainer objects>)

# %%
from sklearn.model_selection import train_test_split
x=np.array(df['power_rating'])
y=df['weight_of_copper']
x_train,x_test,y_train,y_test=train_test_split(x.reshape(-1,1),y,test_size=0.3)

# %%
len(x_train)
# Out:
# 350

# %%
len(y_train)
# Out:
# 350

# %%
len(x_test)
# Out:
# 150

# %%
len(y_test)
# Out:
# 150

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_pred=model.predict(x_test)

# %%
model.score(x_test, y_test)
# Out:
# 0.9999999181448499

# %%
model.predict([[6.29]])
# Out:
# array([19.43473136])
